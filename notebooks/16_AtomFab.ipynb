# %% [markdown]
# # Testing DATA integration through Tango
#
# This notebook checks the real-hardware DATA flow:
#
# 1. Connect to Tango devices.
# 2. Configure the DATA Tango device.
# 3. Acquire a STEM image from ThermoMicroscope.
# 4. Use the returned saved file path to retrieve data through the DATA device.

# %% [markdown]
# ### Quick Start Code Cell

# %%
import os
import json
import time
from getpass import getpass

import tango
import numpy as np
import matplotlib.pyplot as plt
import tifffile

# %% [markdown]
# ## 0. Ping Tango servers

# %%
# ── Config ────────────────────────────────────────────────────────────────────
DB_HOST = "10.46.217.241"
# DB_HOST = "127.0.0.1"
DB_PORT = 9094
# DB_PORT = 9000
server_list = [("stage", "asyncroscopy.hardware.STAGE"),
               ("scan", "asyncroscopy.hardware.SCAN"),
               ("eds", "asyncroscopy.detectors.EDS"),
               ("camera", "asyncroscopy.detectors.CAMERA"),
               ("data", "asyncroscopy.software.DATA"),
               ("corrector", "asyncroscopy.hardware.CORRECTOR"),
               ("microscope", "asyncroscopy.ThermoMicroscope")]
# ─────────────────────────────────────────────────────────────────────────────

PROJECT_DIR = os.path.dirname(os.getcwd())
os.environ["TANGO_HOST"] = f"{DB_HOST}:{DB_PORT}"
env = {**os.environ, "TANGO_HOST": f"{DB_HOST}:{DB_PORT}"}
processes = {}


def wait_for_device(name, timeout=2, interval=1):
    print(f"  Waiting for {name}...", end="", flush=True)
    start = time.time()
    while time.time() - start < timeout:
        try:
            tango.DeviceProxy(name).ping()
            print(f" ✅ ready ({time.time()-start:.1f}s)")
            return True
        except Exception:
            print(".", end="", flush=True)
            time.sleep(interval)
    print(f" ❌ timed out after {timeout}s")
    return False

def check_processes(*names):
    for name in names:
        p = processes[name]
        print(f"\n─── {name} (PID {p.pid}) ───\n  Running: {p.poll() is None}")
        for label, fd in [("STDOUT", p.stdout), ("STDERR", p.stderr)]:
            try:
                print(f"  {label}: {fd.read1(4096).decode() or '(empty)'}")
            except Exception:
                print(f"  {label}: (no output yet)")



if not all(wait_for_device(f"asyncroscopy/{d}/default") for d in ["stage", "scan", "eds", "camera", "data"]):
    print("\n⚠️  Debug info:")
    check_processes("stage", "scan", "eds", "camera", "data")
    raise RuntimeError("One or more device servers failed.")


print("\n✅ All servers ready!")
# Out:
#   Waiting for asyncroscopy/stage/default... ✅ ready (0.2s)
#   Waiting for asyncroscopy/scan/default... ✅ ready (0.2s)
#   Waiting for asyncroscopy/eds/default... ✅ ready (0.2s)
#   Waiting for asyncroscopy/camera/default... ✅ ready (0.2s)
#   Waiting for asyncroscopy/data/default... ✅ ready (0.2s)
#
# ✅ All servers ready!

# %% [markdown]
# ## 1. Connect to devices

# %%
db = tango.Database()
print("Devices registered in Tango DB:\n")
for device in db.get_device_name("*", "*"):
    print(device)
# Out:
# Devices registered in Tango DB:
#
# asyncroscopy/camera/default
# asyncroscopy/corrector/default
# asyncroscopy/data/default
# asyncroscopy/eds/default
# asyncroscopy/flucam/default
# asyncroscopy/microscope/default
# asyncroscopy/scan/default
# asyncroscopy/stage/default
# dserver/CAMERA/camera_instance
# dserver/CORRECTOR/corrector_instance
# dserver/DATA/data_instance
# dserver/DataBaseds/2
# dserver/EDS/eds_instance
# dserver/FLUCAM/flucam_instance
# dserver/SCAN/scan_instance
# dserver/STAGE/stage_instance
# dserver/TangoAccessControl/1
# dserver/TangoTest/test
# dserver/ThermoDigitalTwin/microscope_twin_instance
# dserver/ThermoMicroscope/microscope_instance
# sys/access_control/1
# sys/database/2
# sys/tg_test/1
# test/camera/1
# test/corrector/1
# test/eds/1
# test/microscope/1
# test/microscope_twin/1
# test/scan/1
# test/stage/1

# %%
SCAN_DEVICE = "asyncroscopy/scan/default"
MICROSCOPE_DEVICE = "asyncroscopy/microscope/default"
DATA_DEVICE = "asyncroscopy/data/default"

# %%
scan = tango.DeviceProxy(SCAN_DEVICE)
microscope = tango.DeviceProxy(MICROSCOPE_DEVICE)


for proxy in (scan, microscope):
    proxy.set_timeout_millis(120_000)

print("scan      :", scan.state())
print("microscope:", microscope.state())
# Out:
# scan      : ON
# microscope: ON

# %%
data = tango.DeviceProxy(DATA_DEVICE)
data.set_timeout_millis(120_000)

TILED_HOST = "10.46.217.241"
TILED_PORT = 9091

# TILED_HOST = "127.0.0.1"
# TILED_PORT = 9091

data.host = TILED_HOST
data.port = TILED_PORT
save_path = "D:/microscopedata/tiled/ahoust17/"
data.save_path = save_path

data.set_api_key(getpass("Enter your Tiled API key: "))
print(json.dumps(json.loads(data.get_config()), indent=2))
# Out:
# {
#   "host": "10.46.217.241",
#   "port": 9091,
#   "uri": "http://10.46.217.241:9091",
#   "save_path": "D:/microscopedata/tiled/ahoust17/",
#   "root_path": "",
#   "api_key_configured": true,
#   "tiled_server": "yes",
#   "tiled_server_status": "running; registered"
# }

# %%
# Start a real Tiled server if the configured DATA server is not already reachable.
if str(data.tiled_server).lower() != "yes":
    print("Tiled server is not responding; starting it from the DATA device...")
    config = json.loads(data.start_tiled_server())
else:
    print("Tiled server is already running.")
    config = json.loads(data.get_config())

print(json.dumps(config, indent=2))
if config.get("tiled_server") != "yes":
    raise RuntimeError("Tiled server did not start. Check DATA device logs and save_path permissions.")
# Out:
# Tiled server is not responding; starting it from the DATA device...
# {
#   "host": "10.46.217.241",
#   "port": 9091,
#   "uri": "http://10.46.217.241:9091",
#   "save_path": "D:/microscopedata/tiled/ahoust17/",
#   "root_path": "",
#   "api_key_configured": true,
#   "tiled_server": "yes",
#   "tiled_server_status": "running; registered"
# }

# %%
from tiled.client import from_uri
import matplotlib.pyplot as plt

client = from_uri("http://10.46.217.241:9091", api_key="secret")
list(client)

# %%
import json

recent = json.loads(data.get_recent())
[f["file_name"] for f in recent["files"]]
# Out:
# ['stem_image_haadf_20260522T071920_b026637e.tiff',
#  'stem_image_haadf_20260522T071205_6f292987.tiff',
#  '.asyncroscopy_tiled_catalog.db',
#  'stem_image_haadf_20260522T070827_ad334eaa.tiff',
#  'stem_image_haadf_20260522T065937_1a26b1f5.tiff',
#  'stem_image_haadf_20260520T172827_5894ecd7.tiff']

# %%
# See top-level entries only
file_names = list(client)
file_names
# Out:
# ['stem_image_haadf_20260520T172827_5894ecd',
#  'stem_image_haadf_20260522T065937_1a26b1f',
#  'stem_image_haadf_20260522T070827_ad334eaa.tiff']

# %%
image = client[file_names[2]]


plt.figure()
plt.imshow(image)

# %% [markdown]
# ## 3. Configure a small STEM acquisition

# %%
scan.Activate(["haadf"])
scan.dwell_time = 20e-6
scan.imsize = 128

print("dwell_time:", scan.dwell_time)
print("imsize    :", scan.imsize)
# Out:
# dwell_time: 2e-05
# imsize    : 128

# %% [markdown]
# ## 4. Acquire and inspect the saved path

# %%
saved_path = microscope.get_scanned_image()

print("Saved file:", saved_path)
# Out:
# Saved file: stem_image_haadf_20260522T071920_b026637e

# %%
saved_path = microscope.get_scanned_image()
json.loads(data.register_path(saved_path))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 2
#       1 saved_path = microscope.get_scanned_image()
# ----> 2 json.loads(data.register_path(saved_path))
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/device_proxy.py:2319, in __safe_call.<locals>.safe_call_wrapper(self, *args, **kwargs)
#    2317 if not self._initialized:
#    2318     raise RuntimeError("DeviceProxy object was not fully initialized.")
# -> 2319 return fn(self, *args, **kwargs)
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/device_proxy.py:484, in __DeviceProxy__getattr(self, name)
#     481     if attr_info:
#     482         return __get_attribute_value(self, attr_info, name)
# --> 484     raise AttributeError(name) from cause
#     485 finally:
#     486     del cause
#
# AttributeError: register_path

# %%
image = client[saved_path]


plt.figure(figsize=(8, 8))
plt.imshow(image, cmap='gray')
plt.axis('off')
plt.title(image.split('/')[-1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/utils.py:76, in handle_error(response)
#      75 try:
# ---> 76     raise_for_status(response)
#      77 except httpx.RequestError:
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/utils.py:69, in raise_for_status(response)
#      66 message = message.format(
#      67     response, error_type=error_type, correlation_id=correlation_id
#      68 )
# ---> 69 raise httpx.HTTPStatusError(message, request=request, response=response)
#
# HTTPStatusError: Client error '404 Not Found' for url 'http://10.46.217.241:9091/api/v1/metadata/stem_image_haadf_20260522T070827_ad334eaa'
# For more information, server admin can search server logs for correlation ID 1ea466e9865a0733.
#
# The above exception was the direct cause of the following exception:
#
# ClientError                               Traceback (most recent call last)
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/container.py:355, in Container.__getitem__(self, keys, _ignore_inlined_contents)
#     354 link = self_link + "".join(f"/{key}" for key in keys[i:])
# --> 355 for attempt in retry_context():
#     356     with attempt:
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/stamina/_core.py:581, in _RetryContextIterator.__iter__(self)
#     577 before_sleep = _make_before_sleep(
#     578     self._name, CONFIG, self._args, self._kw, self._cms_to_exit
#     579 )
# --> 581 for r in _t.Retrying(
#     582     before=self._exit_cms,
#     583     before_sleep=before_sleep,
#     584     **self._apply_maybe_test_mode_to_tenacity_kw(CONFIG.testing),
#     585 ):
#     586     yield Attempt(r, self._backoff_for_attempt_number)
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tenacity/__init__.py:438, in BaseRetrying.__iter__(self)
#     437 while True:
# --> 438     do = self.iter(retry_state=retry_state)
#     439     if isinstance(do, DoAttempt):
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tenacity/__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/container.py:357, in Container.__getitem__(self, keys, _ignore_inlined_contents)
#     356         with attempt:
# --> 357             content = handle_error(
#     358                 self.context.http_client.get(
#     359                     link,
#     360                     headers={"Accept": MSGPACK_MIME_TYPE},
#     361                     params={
#     362                         **parse_qs(urlparse(link).query),
#     363                         **params,
#     364                     },
#     365                 )
#     366             ).json()
#     367 except ClientError as err:
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/utils.py:94, in handle_error(response)
#      93     message = f"{exc.response.status_code}: " f"{detail} " f"{exc.request.url}"
# ---> 94     raise ClientError(message, exc.request, exc.response) from exc
#      95 else:
#
# ClientError: 404: No such entry: ['stem_image_haadf_20260522T070827_ad334eaa'] http://10.46.217.241:9091/api/v1/metadata/stem_image_haadf_20260522T070827_ad334eaa
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 image = client[saved_path]
#       2
#       3
#       4 plt.figure(figsize=(8, 8))
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tiled/client/container.py:373, in Container.__getitem__(self, keys, _ignore_inlined_contents)
#     371         if len(err_arg) == 1:
#     372             (err_arg,) = err_arg
# --> 373         raise KeyError(err_arg)
#     374     raise
#     375 item = content["data"]
#
# KeyError: 'stem_image_haadf_20260522T070827_ad334eaa'

# %%
metadata = client[saved_path].metadata

# %%
metadata
# Out:
# {'ImageWidth': 512,
#  'ImageLength': 512,
#  'BitsPerSample': 16,
#  'Compression': <COMPRESSION.NONE: 1>,
#  'PhotometricInterpretation': <PHOTOMETRIC.MINISBLACK: 1>,
#  'StripOffsets': (15734,),
#  'RowsPerStrip': 512,
#  'StripByteCounts': (524288,),
#  'PlanarConfiguration': <PLANARCONFIG.CONTIG: 1>,
#  'ResolutionUnit': <RESUNIT.CENTIMETER: 3>,
#  'FEI_TITAN': '<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<Metadata xmlns:nil="http://schemas.fei.com/Metadata/v1/2013/07" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n  <Core>\n    <Guid>453ea07f-5e21-4d95-86c2-a6a79a95c04b</Guid>\n    <ApplicationSoftware>AutoScript TEM</ApplicationSoftware>\n    <ApplicationSoftwareVersion>1.15.0.484</ApplicationSoftwareVersion>\n  </Core>\n  <Instrument>\n    <ControlSoftwareVersion>3.21.1</ControlSoftwareVersion>\n    <Manufacturer>FEI Company</Manufacturer>\n    <InstrumentClass>Titan</InstrumentClass>\n    <InstrumentModel>Spectra</InstrumentModel>\n    <InstrumentID>4018</InstrumentID>\n    <ComputerName>TITAN52340180</ComputerName>\n  </Instrument>\n  <Acquisition>\n    <AcquisitionStartDatetime>2026-05-20T21:28:00Z</AcquisitionStartDatetime>\n    <AcquisitionDatetime>2026-05-20T21:28:04.3671578Z</AcquisitionDatetime>\n    <SourceType>XFEG</SourceType>\n  </Acquisition>\n  <Optics>\n    <Apertures>\n      <Aperture>\n        <Number>1</Number>\n        <Name>C1</Name>\n        <MechanismType>Motorized</MechanismType>\n        <Type>Cicular</Type>\n        <Diameter>0.002</Diameter>\n        <Index>0</Index>\n      </Aperture>\n      <Aperture>\n        <Number>2</Number>\n        <Name>C2</Name>\n        <MechanismType>Motorized</MechanismType>\n        <Type>Cicular</Type>\n        <Diameter>7e-05</Diameter>\n        <Index>1</Index>\n      </Aperture>\n      <Aperture>\n        <Number>3</Number>\n        <Name>C3</Name>\n        <MechanismType>Motorized</MechanismType>\n        <Type>Cicular</Type>\n        <Diameter>0.002</Diameter>\n        <Index>0</Index>\n      </Aperture>\n      <Aperture>\n        <Number>4</Number>\n        <Name>OBJ</Name>\n        <MechanismType>Motorized</MechanismType>\n        <Type>None</Type>\n        <Diameter>0</Diameter>\n        <Index>0</Index>\n      </Aperture>\n      <Aperture>\n        <Number>5</Number>\n        <Name>SA</Name>\n        <MechanismType>Motorized</MechanismType>\n        <Type>None</Type>\n        <Diameter>0</Diameter>\n        <Index>0</Index>\n      </Aperture>\n    </Apertures>\n    <GunLensSetting>786.904907</GunLensSetting>\n    <ExtractorVoltage>3600.03662</ExtractorVoltage>\n    <AccelerationVoltage>200000</AccelerationVoltage>\n    <SpotIndex>7</SpotIndex>\n    <C2LensIntensity>0.194577896</C2LensIntensity>\n    <C3LensIntensity>0.351422774</C3LensIntensity>\n    <C1LensIntensity>-0.451997418</C1LensIntensity>\n    <ObjectiveLensIntensity>0.823960099</ObjectiveLensIntensity>\n    <IntermediateLensIntensity>0.0603362652</IntermediateLensIntensity>\n    <DiffractionLensIntensity>0.191390786</DiffractionLensIntensity>\n    <Projector1LensIntensity>0.2809157</Projector1LensIntensity>\n    <Projector2LensIntensity>0.910340794</Projector2LensIntensity>\n    <LorentzLensIntensity>0</LorentzLensIntensity>\n    <MiniCondenserLensIntensity>0.343435886</MiniCondenserLensIntensity>\n    <BeamDiameter>0</BeamDiameter>\n    <BeamConvergence>0.0299843314</BeamConvergence>\n    <ScreenCurrent>2.53515935e-14</ScreenCurrent>\n    <LastMeasuredScreenCurrent>2.53515935e-14</LastMeasuredScreenCurrent>\n    <IlluminationIntensityNormalized>0.194577896</IlluminationIntensityNormalized>\n    <FullScanFieldOfView>\n      <X>3.72184104e-07</X>\n      <Y>3.72184104e-07</Y>\n    </FullScanFieldOfView>\n    <BeamTilt>\n      <X>4.05897982e-18</X>\n      <Y>-6.81691992e-18</Y>\n    </BeamTilt>\n    <ImageShift>\n      <X>0</X>\n      <Y>0</Y>\n    </ImageShift>\n    <BeamShift>\n      <X>0</X>\n      <Y>0</Y>\n    </BeamShift>\n    <SampleTiltCorrectionOn>false</SampleTiltCorrectionOn>\n    <Focus>0</Focus>\n    <STEMFocus>0</STEMFocus>\n    <Defocus>0</Defocus>\n    <NominalMagnification>226274.17</NominalMagnification>\n    <HighMagnificationMode>None</HighMagnificationMode>\n    <OperatingMode>STEM</OperatingMode>\n    <TEMOperatingSubMode>None</TEMOperatingSubMode>\n    <ProjectorMode>Diffraction</ProjectorMode>\n    <EFTEMOn>fals ...

# %%
import tifffile
import pprint

image_path = save_path + saved_path + '.tiff'

with tifffile.TiffFile(image_path) as tif:
    page = tif.pages[0]

    print("="*80)
    print("ALL TIFF TAGS")
    print("="*80)

    for tag in page.tags.values():
        print(f"\n{tag.name}")
        print("-" * 50)
        
        try:
            if isinstance(tag.value, bytes):
                print(tag.value[:500])  # avoid gigantic dump
            else:
                pprint.pprint(tag.value)
        except Exception as e:
            print(f"<could not print> {e}")

    print("\n" + "="*80)
    print("TIFF SERIES")
    print("="*80)
    pprint.pprint(tif.series)

    print("\n" + "="*80)
    print("TIFF FLAGS")
    print("="*80)
    print("is_imagej:", tif.is_imagej)
    print("is_ome:", tif.is_ome)
    print("is_lsm:", tif.is_lsm)
    print("is_scn:", tif.is_scn)
    print("is_shaped:", tif.is_shaped)
# Out:
# ================================================================================
# ALL TIFF TAGS
# ================================================================================
#
# ImageWidth
# --------------------------------------------------
# 512
#
# ImageLength
# --------------------------------------------------
# 512
#
# BitsPerSample
# --------------------------------------------------
# 16
#
# Compression
# --------------------------------------------------
# <COMPRESSION.NONE: 1>
#
# PhotometricInterpretation
# --------------------------------------------------
# <PHOTOMETRIC.MINISBLACK: 1>
#
# StripOffsets
# --------------------------------------------------
# (15734,)
#
# RowsPerStrip
# --------------------------------------------------
# 512
#
# StripByteCounts
# --------------------------------------------------
# (524288,)
#
# PlanarConfiguration
# --------------------------------------------------
# <PLANARCONFIG.CONTIG: 1>
#
# ResolutionUnit
# --------------------------------------------------
# <RESUNIT.CENTIMETER: 3>
#
# FEI_TITAN
# --------------------------------------------------
# ("<?xml version='1.0' encoding='utf-8'?>\n"
#  '<Metadata xmlns:nil="http://schemas.fei.com/Metadata/v1/2013/07" '
#  'xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n'
#  '  <Core>\n'
#  '    <Guid>453ea07f-5e21-4d95-86c2-a6a79a95c04b</Guid>\n'
#  '    <ApplicationSoftware>AutoScript TEM</ApplicationSoftware>\n'
#  '    <ApplicationSoftwareVersion>1.15.0.484</ApplicationSoftwareVersion>\n'
#  '  </Core>\n'
#  '  <Instrument>\n'
#  '    <ControlSoftwareVersion>3.21.1</ControlSoftwareVersion>\n'
#  '    <Manufacturer>FEI Company</Manufacturer>\n'
#  '    <InstrumentClass>Titan</InstrumentClass>\n'
#  '    <InstrumentModel>Spectra</InstrumentModel>\n'
#  '    <InstrumentID>4018</InstrumentID>\n'
#  '    <ComputerName>TITAN52340180</ComputerName>\n'
#  '  </Instrument>\n'
#  '  <Acquisition>\n'
#  '    '
#  '<AcquisitionStartDatetime>2026-05-20T21:28:00Z</AcquisitionStartDatetime>\n'
#  '    <AcquisitionDatetime>2026-05-20T21:28:04.3671578Z</AcquisitionDatetime>\n'
#  '    <SourceType>XFEG</SourceType>\n'
#  '  </Acquisition>\n'
#  '  <Optics>\n'
#  '    <Apertures>\n'
#  '      <Aperture>\n'
#  '        <Number>1</Number>\n'
#  '        <Name>C1</Name>\n'
#  '        <MechanismType>Motorized</MechanismType>\n'
#  '        <Type>Cicular</Type>\n'
#  '        <Diameter>0.002</Diameter>\n'
#  '        <Index>0</Index>\n'
#  '      </Aperture>\n'
#  '      <Aperture>\n'
#  '        <Number>2</Number>\n'
#  '        <Name>C2</Name>\n'
#  '        <MechanismType>Motorized</MechanismType>\n'
#  '        <Type>Cicular</Type>\n'
#  '        <Diameter>7e-05</Diameter>\n'
#  '        <Index>1</Index>\n'
#  '      </Aperture>\n'
#  '      <Aperture>\n'
#  '        <Number>3</Number>\n'
#  '        <Name>C3</Name>\n'
#  '        <MechanismType>Motorized</MechanismType>\n'
#  '        <Type>Cicular</Type>\n'
#  '        <Diameter>0.002</Diameter>\n'
#  '        <Index>0</Index>\n'
#  '      </Aperture>\n'
#  '      <Aperture>\n'
#  '        <Number>4</Number>\n'
#  '        <Name>OBJ</Name>\n'
#  '        <MechanismType>Motorized</MechanismType>\n'
#  '        <Type>None</Type>\n'
#  '        <Diameter>0</Diameter>\n'
#  '        <Index>0</Index>\n'
#  '      </Aperture>\n'
#  '      <Aperture>\n'
#  '        <Number>5</Number>\n'
#  '        <Name>SA</Name>\n'
#  '        <MechanismType>Motorized</MechanismType>\n'
#  '        <Type>None</Type>\n'
#  '        <Diameter>0</Diameter>\n'
#  '        <Index>0</Index>\n'
#  '      </Aperture>\n'
#  '    </Apertures>\n'
#  '    <GunLensSetting>786.904907</GunLensSetting>\n'
#  '    <ExtractorVoltage>3600.03662</ExtractorVoltage>\n'
#  '    <AccelerationVoltage>200000</AccelerationVoltage>\n'
#  '    <SpotIndex>7</SpotIndex>\n'
#  '    <C2LensIntensity>0.194577896</C2LensIntensity>\n'
#  '    <C3LensIntensity>0.351422774</C3LensIntensity>\n'
#  '    <C1LensIntensity>-0.451997418</C1LensIntensity>\n'
#  '    <ObjectiveLensIntensity>0.823960099</ObjectiveLensIntensity>\n'
#  '    <IntermediateLensIntensity>0.0603362652</IntermediateLensIntensity>\n'
#  '    <DiffractionLensIntensity>0.191390786</DiffractionLensIntensity>\n'
#  '    <Projector1LensIntensity>0.2809157</Projector1LensIntensity>\n'
#  '    <Projector2LensIntensity>0.910340794</Projector2LensIntensity>\n'
#  '    <LorentzLensIntensity>0</LorentzLensIntensity>\n'
#  '    <MiniCondenserLensIntensity>0.343435886</MiniCondenserLensIntensity>\n'
#  '    <BeamDiameter>0</BeamDiameter>\n'
#  '    <BeamConvergence>0.0299843314</BeamConvergence>\n'
#  '    <ScreenCurrent>2.53515935e-14</ScreenCurrent>\n'
#  '    <LastMeasuredScreenCurrent>2.53515935e-14</LastMeasuredScreenCurrent>\n'
#  '    '
#  '<IlluminationIntensityNormalized>0.194577896</IlluminationIntensityNormalized>\n'
#  '    <FullScanFieldOfView>\n'
#  '      <X>3.72184104e-07</X>\n'
#  '      <Y>3.72184104e-07</Y>\n'
#  '    </FullScanFieldOfView>\n'
#  '    <BeamTilt>\n'
#  '      <X>4.05897982e-18</X>\n'
#  '      <Y>-6.81691992e-18</Y>\n'
#  '    </BeamTilt>\n'
#  '    <ImageShift>\n'
#  '      <X>0</X>\n'
#  '      <Y>0</Y>\n'
#  '    </ImageShift>\n'
#  '    <BeamShift>\n'
#  '      <X>0</X>\n'
#  '      <Y>0</Y>\n'
#  '    </BeamShift>\n'
#  '    <SampleTiltCorrectionOn>false</SampleTiltCorrectionOn>\n'
#  '    <Focus>0</Focus>\n'
#  '    <STEMFocus>0</STEMFocus>\n'
#  '    <Defocus>0</Defocus>\n'
#  '    <NominalMagnification>226274.17</NominalMagnification>\n'
#  '    <HighMagnificationMode>None</HighMagnificationMode>\n'
#  '    <OperatingMode>STEM</OperatingMode>\n'
#  '    <TEMOperatingSubMode>None</TEMOperatingSubMode>\n'
#  '    <ProjectorMode>Diffraction</ProjectorMode>\n'
#  '    <EFTEMOn>false</EFTEMOn>\n'
#  '    <ObjectiveLensMode>HM</ObjectiveLensMode>\n'
#  '    <IlluminationMode>Probe</IlluminationMode>\n'
#  '    <ProbeMode>Nanoprobe</ProbeMode>\n'
#  '    <CameraLength>0.091</CameraLength>\n'
#  '  </Optics>\n'
#  '  <StageSettings>\n'
#  '    <StagePosition>\n'
#  '      <X>1.0716e-07</X>\n'
#  '      <Y>1.17198e-07</Y>\n'
#  '      <Z>-8.76e-09</Z>\n'
#  '      <Tilt>\n'
#  '        <Alpha>-3.136e-06</Alpha>\n'
#  '        <Beta>0.000313562778</Beta>\n'
#  '      </Tilt>\n'
#  '    </StagePosition>\n'
#  '    <HolderType>DoubleTilt</HolderType>\n'
#  '  </StageSettings>\n'
#  '  <ScanSettings>\n'
#  '    <DwellTime>1e-05</DwellTime>\n'
#  '    <ScanSize>\n'
#  '      <Width>512</Width>\n'
#  '      <Height>512</Height>\n'
#  '    </ScanSize>\n'
#  '    <ScanArea>\n'
#  '      <X>0</X>\n'
#  '      <Y>0</Y>\n'
#  '      <Width>512</Width>\n'
#  '      <Height>512</Height>\n'
#  '    </ScanArea>\n'
#  '    <MainsLockOn>false</MainsLockOn>\n'
#  '    <LineTime>0.00616</LineTime>\n'
#  '    <LineIntegrationCount>1</LineIntegrationCount>\n'
#  '    <LineInterlacing>1</LineInterlacing>\n'
#  '    <FrameTime>3.15393</FrameTime>\n'
#  '    <ScanRotation>0</ScanRotation>\n'
#  '  </ScanSettings>\n'
#  '  <VacuumProperties>\n'
#  '    <VacuumMode>Ready</VacuumMode>\n'
#  '  </VacuumProperties>\n'
#  '  <Detectors>\n'
#  '    <ScanningDetector>\n'
#  '      <DetectorName>BF-S</DetectorName>\n'
#  '      <DetectorType>ScanningDetector</DetectorType>\n'
#  '      <Inserted>false</Inserted>\n'
#  '      <Enabled>true</Enabled>\n'
#  '      <Gain>24</Gain>\n'
#  '      <Offset>0</Offset>\n'
#  '      <CollectionAngleRange>\n'
#  '        <Begin>0</Begin>\n'
#  '        <End>0</End>\n'
#  '      </CollectionAngleRange>\n'
#  '    </ScanningDetector>\n'
#  '    <ScanningDetector>\n'
#  '      <DetectorName>DF-S</DetectorName>\n'
#  '      <DetectorType>ScanningDetector</DetectorType>\n'
#  '      <Inserted>false</Inserted>\n'
#  '      <Enabled>true</Enabled>\n'
#  '      <Gain>21.75261</Gain>\n'
#  '      <Offset>0</Offset>\n'
#  '      <CollectionAngleRange>\n'
#  '        <Begin>0</Begin>\n'
#  '        <End>0</End>\n'
#  '      </CollectionAngleRange>\n'
#  '    </ScanningDetector>\n'
#  '    <ScanningDetector>\n'
#  '      <DetectorName>HAADF</DetectorName>\n'
#  '      <DetectorType>ScanningDetector</DetectorType>\n'
#  '      <Inserted>true</Inserted>\n'
#  '      <Enabled>true</Enabled>\n'
#  '      <Gain>20.8404707</Gain>\n'
#  '      <Offset>-1.752</Offset>\n'
#  '      <CollectionAngleRange>\n'
#  '        <Begin>0.0728785469</Begin>\n'
#  '        <End>0.2</End>\n'
#  '      </CollectionAngleRange>\n'
#  '    </ScanningDetector>\n'
#  '    <AnalyticalDetector>\n'
#  '      <DetectorName>SuperXG21</DetectorName>\n'
#  '      <DetectorType>AnalyticalDetector</DetectorType>\n'
#  '      <Inserted>true</Inserted>\n'
#  '      <Enabled>false</Enabled>\n'
#  '      <ElevationAngle>0.31415927</ElevationAngle>\n'
#  '      <AzimuthAngle>0.785398163</AzimuthAngle>\n'
#  '      <CollectionAngle>0.7</CollectionAngle>\n'
#  '      <Dispersion>10</Dispersion>\n'
#  '      <PulseProcessTime>3e-06</PulseProcessTime>\n'
#  '      <ShutterState>Closed</ShutterState>\n'
#  '      <OffsetEnergy>-250</OffsetEnergy>\n'
#  '      <ElectronicsNoise>25.36</ElectronicsNoise>\n'
#  '    </AnalyticalDetector>\n'
#  '    <AnalyticalDetector>\n'
#  '      <DetectorName>SuperXG22</DetectorName>\n'
#  '      <DetectorType>AnalyticalDetector</DetectorType>\n'
#  '      <Inserted>true</Inserted>\n'
#  '      <Enabled>false</Enabled>\n'
#  '      <ElevationAngle>0.31415927</ElevationAngle>\n'
#  '      <AzimuthAngle>2.35619449</AzimuthAngle>\n'
#  '      <CollectionAngle>0.7</CollectionAngle>\n'
#  '      <Dispersion>10</Dispersion>\n'
#  '      <PulseProcessTime>3e-06</PulseProcessTime>\n'
#  '      <ShutterState>Closed</ShutterState>\n'
#  '      <OffsetEnergy>-250</OffsetEnergy>\n'
#  '      <ElectronicsNoise>25.17</ElectronicsNoise>\n'
#  '    </AnalyticalDetector>\n'
#  '    <AnalyticalDetector>\n'
#  '      <DetectorName>SuperXG23</DetectorName>\n'
#  '      <DetectorType>AnalyticalDetector</DetectorType>\n'
#  '      <Inserted>true</Inserted>\n'
#  '      <Enabled>false</Enabled>\n'
#  '      <ElevationAngle>0.31415927</ElevationAngle>\n'
#  '      <AzimuthAngle>3.92699082</AzimuthAngle>\n'
#  '      <CollectionAngle>0.7</CollectionAngle>\n'
#  '      <Dispersion>10</Dispersion>\n'
#  '      <PulseProcessTime>3e-06</PulseProcessTime>\n'
#  '      <ShutterState>Closed</ShutterState>\n'
#  '      <OffsetEnergy>-250</OffsetEnergy>\n'
#  '      <ElectronicsNoise>24.35</ElectronicsNoise>\n'
#  '    </AnalyticalDetector>\n'
#  '    <AnalyticalDetector>\n'
#  '      <DetectorName>SuperXG24</DetectorName>\n'
#  '      <DetectorType>AnalyticalDetector</DetectorType>\n'
#  '      <Inserted>true</Inserted>\n'
#  '      <Enabled>false</Enabled>\n'
#  '      <ElevationAngle>0.31415927</ElevationAngle>\n'
#  '      <AzimuthAngle>5.49778714</AzimuthAngle>\n'
#  '      <CollectionAngle>0.7</CollectionAngle>\n'
#  '      <Dispersion>10</Dispersion>\n'
#  '      <PulseProcessTime>3e-06</PulseProcessTime>\n'
#  '      <ShutterState>Closed</ShutterState>\n'
#  '      <OffsetEnergy>-250</OffsetEnergy>\n'
#  '      <ElectronicsNoise>25.46</ElectronicsNoise>\n'
#  '    </AnalyticalDetector>\n'
#  '    <ImagingDetector>\n'
#  '      <DetectorName>BM-Ceta</DetectorName>\n'
#  '      <DetectorType>ImagingDetector</DetectorType>\n'
#  '      <Binning>\n'
#  '        <X>4</X>\n'
#  '        <Y>4</Y>\n'
#  '      </Binning>\n'
#  '      <ReadoutArea>\n'
#  '        <X>0</X>\n'
#  '        <Y>0</Y>\n'
#  '        <Width>1024</Width>\n'
#  '        <Height>1024</Height>\n'
#  '      </ReadoutArea>\n'
#  '      <ExposureTime>0.1</ExposureTime>\n'
#  '      <Shutters>\n'
#  '        <Shutter type="Electrostatic" position="PostSpecimen"/>\n'
#  '      </Shutters>\n'
#  '      <DarkGainCorrectionType>DarkGain</DarkGainCorrectionType>\n'
#  '    </ImagingDetector>\n'
#  '    <ImagingDetector>\n'
#  '      <DetectorName>EF-CCD</DetectorName>\n'
#  '      <DetectorType>ImagingDetector</DetectorType>\n'
#  '      <Binning>\n'
#  '        <X>4</X>\n'
#  '        <Y>4</Y>\n'
#  '      </Binning>\n'
#  '      <ReadoutArea>\n'
#  '        <X>0</X>\n'
#  '        <Y>0</Y>\n'
#  '        <Width>1024</Width>\n'
#  '        <Height>1024</Height>\n'
#  '      </ReadoutArea>\n'
#  '      <ExposureTime>0.1</ExposureTime>\n'
#  '      <Shutters>\n'
#  '        <Shutter type="Electrostatic" position="PostSpecimen"/>\n'
#  '      </Shutters>\n'
#  '      <DarkGainCorrectionType>DarkGain</DarkGainCorrectionType>\n'
#  '    </ImagingDetector>\n'
#  '    <ImagingDetector>\n'
#  '      <DetectorName>Flucam</DetectorName>\n'
#  '      <DetectorType>ImagingDetector</DetectorType>\n'
#  '      <Gain>0.7</Gain>\n'
#  '      <Binning>\n'
#  '        <X>1</X>\n'
#  '        <Y>1</Y>\n'
#  '      </Binning>\n'
#  '      <ReadoutArea>\n'
#  '        <X>0</X>\n'
#  '        <Y>0</Y>\n'
#  '        <Width>1024</Width>\n'
#  '        <Height>1024</Height>\n'
#  '      </ReadoutArea>\n'
#  '      <ExposureTime>0.0403408947</ExposureTime>\n'
#  '      <Shutters>\n'
#  '        <Shutter type="Electrostatic" position="None"/>\n'
#  '      </Shutters>\n'
#  '      <DarkGainCorrectionType>DarkGain</DarkGainCorrectionType>\n'
#  '    </ImagingDetector>\n'
#  '  </Detectors>\n'
#  '  <BinaryResult>\n'
#  '    <Detector>HAADF</Detector>\n'
#  '    <PixelSize>\n'
#  '      <X unit="m" unitPrefixPower="1">7.269221e-10</X>\n'
#  '      <Y unit="m" unitPrefixPower="1">7.269221e-10</Y>\n'
#  '    </PixelSize>\n'
#  '    <Offset>\n'
#  '      <X>-1.86092058e-07</X>\n'
#  '      <Y>-1.86092058e-07</Y>\n'
#  '    </Offset>\n'
#  '    <DetectorIndex>5</DetectorIndex>\n'
#  '  </BinaryResult>\n'
#  '  <CustomPropertyGroup>\n'
#  '    <CustomProperties scope="">\n'
#  '      <CustomProperty name="Detectors[SuperX1].IncidentAngle" '
#  'value="0.09459684" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].DistanceToSample" '
#  'value="12.42" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].CommercialName" '
#  'value="Super-X G2" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].DetectorConfigID" '
#  'value="3101e35a-08ec-4b3d-9108-6aa5d0e49281" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].IncidentAngle" '
#  'value="0.09459684" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].DistanceToSample" '
#  'value="12.42" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].CommercialName" '
#  'value="Super-X G2" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].DetectorConfigID" '
#  'value="3101e35a-08ec-4b3d-9108-6aa5d0e49281" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].IncidentAngle" '
#  'value="0.09459684" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].DistanceToSample" '
#  'value="12.42" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].CommercialName" '
#  'value="Super-X G2" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].DetectorConfigID" '
#  'value="3101e35a-08ec-4b3d-9108-6aa5d0e49281" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].IncidentAngle" '
#  'value="0.09459684" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].DistanceToSample" '
#  'value="12.42" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].CommercialName" '
#  'value="Super-X G2" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].DetectorConfigID" '
#  'value="3101e35a-08ec-4b3d-9108-6aa5d0e49281" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Aperture[C1].Name" value="2000" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="Aperture[C2].Name" value="70" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="Aperture[C3].Name" value="2000" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="Aperture[OBJ].Name" value="None" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="Aperture[SA].Name" value="None" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="StemMagnification" value="225000" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Optics.MonoSpotSize" value="&lt;=11" '
#  'rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[EF-CCD].CommercialName" '
#  'value="Continuum 1065" rawdatatype="String"/>\n'
#  '      <CustomProperty name="Detectors[EF-CCD].ElectronCounted" value="False" '
#  'rawdatatype="Boolean"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].SpectrumBeginEnergy" '
#  'value="120" rawdatatype="Int"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].PulsePairResolutionTime" '
#  'value="5E-07" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].BilatThresholdHi" '
#  'value="0.005039" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].KMin" value="120" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX1].KMax" value="180" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].SpectrumBeginEnergy" '
#  'value="120" rawdatatype="Int"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].PulsePairResolutionTime" '
#  'value="5E-07" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].BilatThresholdHi" '
#  'value="0.005039" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].KMin" value="120" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX2].KMax" value="180" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].SpectrumBeginEnergy" '
#  'value="120" rawdatatype="Int"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].PulsePairResolutionTime" '
#  'value="5E-07" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].BilatThresholdHi" '
#  'value="0.005039" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].KMin" value="120" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX3].KMax" value="180" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].SpectrumBeginEnergy" '
#  'value="120" rawdatatype="Int"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].PulsePairResolutionTime" '
#  'value="5E-07" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].BilatThresholdHi" '
#  'value="0.005039" rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].KMin" value="120" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Detectors[SuperX4].KMax" value="180" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A11" value="1" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A12" value="0" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A13" value="0" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A21" value="0" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A22" value="1" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="Scan.ScanTransformation.A23" value="0" '
#  'rawdatatype="Double"/>\n'
#  '      <CustomProperty name="IlluminationIntensity" value="0" type="double" '
#  'rawdatatype="Double"/>\n'
#  '    </CustomProperties>\n'
#  '  </CustomPropertyGroup>\n'
#  '</Metadata>')
#
# ================================================================================
# TIFF SERIES
# ================================================================================
# [<tifffile.TiffPageSeries 0 uniform>]
#
# ================================================================================
# TIFF FLAGS
# ================================================================================
# is_imagej: False
# is_ome: False
# is_lsm: False
# is_scn: False
# is_shaped: False

# %%
def get_image():
    saved_path = microscope.get_scanned_image()
    image_path = save_path + saved_path + '.tiff'
    
    with tifffile.TiffFile(image_path) as tif:
        img, page = tif.asarray(), tif.pages[0]
        metadata = {tag.name: tag.value for tag in page.tags.values()}

    return img, metadata

# %% [markdown]
# ## 5. Check recent files from the DATA device

# %%
print("Tiled root entries:")
try:
    print(json.dumps(json.loads(data.list_root()), indent=2)[:4000])
except Exception as exc:
    print("Could not list Tiled root:", exc)

recent = json.loads(data.get_recent())
print("\nRecent files visible to the DATA Tango device process:")
print(json.dumps(recent, indent=2)[:4000])
# Out:
# Tiled root entries:
# {
#   "path": "",
#   "entries": []
# }
#
# Recent files visible to the DATA Tango device process:
# {
#   "save_path": "/Users/austin/Desktop/new_data/",
#   "files": [
#     {
#       "path": "/Users/austin/Desktop/new_data/stem_image_haadf_20260520T172827_5894ecd7.tiff",
#       "file_name": "stem_image_haadf_20260520T172827_5894ecd7.tiff",
#       "relative_path": "stem_image_haadf_20260520T172827_5894ecd7.tiff",
#       "size_bytes": 540022,
#       "modified_time": 1779312508.0074947
#     },
#     {
#       "path": "/Users/austin/Desktop/new_data/.asyncroscopy_tiled_catalog.db",
#       "file_name": ".asyncroscopy_tiled_catalog.db",
#       "relative_path": ".asyncroscopy_tiled_catalog.db",
#       "size_bytes": 122880,
#       "modified_time": 1779307855.9912214
#     }
#   ]
# }

# %% [markdown]
# ## 6. Resolve the saved path through Tiled

# %%
def get_data_with_retry(saved_path, timeout=30, interval=2):
    start = time.time()
    last_error = None
    while time.time() - start < timeout:
        try:
            return json.loads(data.get_data(saved_path))
        except Exception as exc:
            last_error = exc
            print("Tiled lookup not ready yet:", exc)
            time.sleep(interval)

    raise RuntimeError(f"Could not resolve data through Tiled after {timeout}s") from last_error

data = get_data_with_retry(saved_path)

if isinstance(data, dict):
    summary = {k: data[k] for k in data.keys() if k != "data"}
    print(json.dumps(summary, indent=2)[:4000])
else:
    print(type(data), str(data)[:1000])
# Out:
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# Tiled lookup not ready yet: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
# ---------------------------------------------------------------------------
# DevFailed                                 Traceback (most recent call last)
# Cell In[12], line 10, in get_data_with_retry(saved_path, timeout, interval)
#       8             last_error = exc
#       9             print("Tiled lookup not ready yet:", exc)
# ---> 10             time.sleep(interval)
#      11
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/device_proxy.py:358, in __get_command_func.<locals>.f(*args, **kwds)
#     357 def f(*args, **kwds):
# --> 358     return dp.command_inout(name, *args, **kwds)
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py:231, in green.<locals>.decorator.<locals>.greener(obj, *args, **kwargs)
#     230 executor = get_object_executor(obj, green_mode)
# --> 231 return executor.run(fn, args, kwargs, wait=wait, timeout=timeout)
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py:121, in AbstractExecutor.run(self, fn, args, kwargs, wait, timeout)
#     120 if not self.asynchronous or not self.in_executor_context():
# --> 121     return fn(*args, **kwargs)
#     122 # Asynchronous delegation
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/connection.py:72, in __Connection__command_inout(self, name, cmd_param)
#      39 """
#      40 command_inout( self, cmd_name, cmd_param=None, __GREEN_KWARGS__) -> any
#      41
#    (...)     70     For commands with a DEV_STRING input argument, invalid data will now raise TypeError instead of SystemError.
#      71 """
# ---> 72 r = Connection.command_inout_raw(self, name, cmd_param)
#      73 if isinstance(r, DeviceData):
#
# File ~/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/connection.py:112, in __Connection__command_inout_raw(self, cmd_name, cmd_param)
#     111 param = _get_command_inout_param(self, cmd_name, cmd_param)
# --> 112 return self.__command_inout(cmd_name, param)
#
# DevFailed: DevFailed[
#     DevError[
#         desc = KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         origin = Traceback (most recent call last):
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/server.py", line 1790, in wrapped_command_method
#                 return get_worker().execute(cmd_method, *args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/.venv/lib/python3.12/site-packages/tango/green.py", line 110, in execute
#                 return fn(*args, **kwargs)
#                        ^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 211, in get_data
#                 return json.dumps(self._json_ready(self._read_node(self._node_for_path_or_saved_path(saved_path_or_tiled_path))))
#                                                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               File "/Users/austin/Documents/GitHub/asyncroscopy/asyncroscopy/software/DATA.py", line 274, in _node_for_path_or_saved_path
#                 raise KeyError("Could not resolve path in Tiled. Tried: " + "; ".join(errors))
#             KeyError: "Could not resolve path in Tiled. Tried: stem_image_haadf_20260520T172827_5894ecd7: 'stem_image_haadf_20260520T172827_5894ecd7'"
#         reason = PyDs_PythonError
#         severity = ERR
#     ],
#     DevError[
#         desc = Cannot execute command
#         origin = virtual CORBA::Any *PyCmd::execute(Tango::DeviceImpl *, const CORBA::Any &) at (/Users/gitlab/builds/tango-controls/pytango/ext/server/command.cpp:87)
#         reason = PyDs_UnexpectedFailure
#         severity = ERR
#     ],
#     DevError[
#         desc = Failed to execute command_inout on device asyncroscopy/data/default, command get_data
#         origin = virtual DeviceData Tango::Connection::command_inout(const std::string &, const DeviceData &) at (/Users/runner/miniforge3/conda-bld/cpptango_1758200193404/work/src/client/devapi_base.cpp:2029)
#         reason = API_CommandFailed
#         severity = ERR
#     ]
# ]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 14
#      10             time.sleep(interval)
#      11
#      12     raise RuntimeError(f"Could not resolve data through Tiled after {timeout}s") from last_error
#      13
# ---> 14 data = get_data_with_retry(saved_path)
#      15
#      16 if isinstance(data, dict):
#      17     summary = {k: data[k] for k in data.keys() if k != "data"}
#
# Cell In[12], line 10, in get_data_with_retry(saved_path, timeout, interval)
#       6             return json.loads(data.get_data(saved_path))
#       7         except Exception as exc:
#       8             last_error = exc
#       9             print("Tiled lookup not ready yet:", exc)
# ---> 10             time.sleep(interval)
#      11
#      12     raise RuntimeError(f"Could not resolve data through Tiled after {timeout}s") from last_error
#
# KeyboardInterrupt:

# %% [markdown]
# ## 7. Plot if Tiled returned an array

# %%
if isinstance(data, dict) and data.get("type") == "ndarray":
    image = np.asarray(data["data"], dtype=np.dtype(data["dtype"]))
    image = image.reshape(data["shape"])

    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(image, cmap="gray", interpolation="none")
    ax.set_title("HAADF from Tiled")
    ax.axis("off")
    plt.tight_layout()
    plt.show()
else:
    print("Tiled did not return a direct ndarray. Inspect data and traverse the returned node/path as needed.")
